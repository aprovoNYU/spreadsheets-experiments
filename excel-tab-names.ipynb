# %% [markdown]
# # Get Excel Tab Names for manual coding

# %%
import pandas as pd
from datetime import datetime

# %%
##https://stackoverflow.com/questions/17977540/pandas-looking-up-the-list-of-sheets-in-an-excel-file
def sheet_names(rec_id,filekey):
    try:
        xl = pd.ExcelFile(f'sample_spreadsheets_2025-12-03/{rec_id}/{filekey}')
        return xl.sheet_names
    except:
        return 'could not parse'

# %%
sheet_names('14522238','Bufasi et al. (2024)_ Pre_post_results.xlsx')
# Out:
# ['Pre-Test']

# %%
# import sample recs dataframe
#https://www.geeksforgeeks.org/python-pandas-series-from_csv/
sample_recs_df = pd.read_csv('zenodo_spreadsheet_files_df_100recs_sample_2025-12-03_04-54_PM.csv')

# %%
sample_recs_df
# Out:
#     df_index                                fileid  \
# 0       6405  8bce9902-0346-4656-82ec-b6b1d6bef240
# 1       3685  a2436cec-dba4-4440-a919-8b2fdcaee190
# 2      20315  90a13ff8-c322-44bc-8a77-bc1b8c333723
# 3      11417  a9de2fe1-0292-4744-8479-ebf337336b58
# 4       5420  e1d21bb4-c45f-4d8f-a0b1-95dc4e662951
# ..       ...                                   ...
# 95    252646  5d586cfd-4206-4c42-bce1-54c13401d0d4
# 96    248860  109b149e-3046-4c43-b7d7-9207ac833883
# 97    234789  89141bcd-2ec7-449f-ac40-a477008ca8f7
# 98    249525  024ef7a0-8c2a-4d3d-8591-e27a23c57b77
# 99    235022  4bf5172e-c1aa-4c95-a401-5f76e617bfef
#
#                                         filekey  filesize  \
# 0                     sg512m9d001-178_cmap.xlsx  14555195
# 1        Water Safety Plan Assessment Form.xlsx     18478
# 2        BES LTER Base Cations Data Upload.xlsx     48829
# 3                   Project-3740971-DwC-occ.csv    897957
# 4                    COVID-19-data-sharing.xlsx    205131
# ..                                          ...       ...
# 95                                   icrmsd.csv   5499659
# 96                       LPL1_November_2024.csv  10379269
# 97             VZ4_013_021_VSCHT_S_0347_v1.xlsx     86988
# 98        Underpasses_Dataset_2024_Complete.csv    374904
# 99  Bufasi et al. (2024)_ Pre_post_results.xlsx     12928
#
#                             filechecksum  \
# 0   md5:75e68958d0720acde89be59b5c7e11e8
# 1   md5:1dfc6aba3e40f93696e64f113026d35c
# 2   md5:7edfb3ab46d7fdc52bc727e829e8cae6
# 3   md5:34e2901094489cc08aea5c9c5a90f2bf
# 4   md5:562aa3a85cb4d359db88485f39ba8c5c
# ..                                   ...
# 95  md5:769e52d8490cf6a64c0fb420546e4bd1
# 96  md5:4f10d54d1dc7119a871d63d66797353d
# 97  md5:191b3d532e484b996b8f9faba6bf13c2
# 98  md5:57618c76b669aad210bbb5560d155a93
# 99  md5:5c40e27273da10914e93ac6b3ed6c53d
#
#                                        filelinks.self        id  filekey_len  \
# 0   https://zenodo.org/api/records/3700108/files/s...   3700108           25
# 1   https://zenodo.org/api/records/3842933/files/W...   3842933           38
# 2   https://zenodo.org/api/records/3938988/files/B...   3938988           38
# 3   https://zenodo.org/api/records/3974090/files/P...   3974090           27
# 4   https://zenodo.org/api/records/4246082/files/C...   4246082           26
# ..                                                ...       ...          ...
# 95  https://zenodo.org/api/records/14200591/files/...  14200591           10
# 96  https://zenodo.org/api/records/14257140/files/...  14257140           22
# 97  https://zenodo.org/api/records/14267476/files/...  14267476           32
# 98  https://zenodo.org/api/records/14330681/files/...  14330681           37
# 99  https://zenodo.org/api/records/14522238/files/...  14522238           43
#
#    filetype                          filename_noext  filename_noext_len  \
# 0     .xlsx                    sg512m9d001-178_cmap                  20
# 1     .xlsx       Water Safety Plan Assessment Form                  33
# 2     .xlsx       BES LTER Base Cations Data Upload                  33
# 3      .csv                 Project-3740971-DwC-occ                  23
# 4     .xlsx                   COVID-19-data-sharing                  21
# ..      ...                                     ...                 ...
# 95     .csv                                  icrmsd                   6
# 96     .csv                      LPL1_November_2024                  18
# 97    .xlsx             VZ4_013_021_VSCHT_S_0347_v1                  27
# 98     .csv       Underpasses_Dataset_2024_Complete                  33
# 99    .xlsx  Bufasi et al. (2024)_ Pre_post_results                  38
#
#     filesize_mb  filesize_gb
# 0     14.555195     0.014555
# 1      0.018478     0.000018
# 2      0.048829     0.000049
# 3      0.897957     0.000898
# 4      0.205131     0.000205
# ..          ...          ...
# 95     5.499659     0.005500
# 96    10.379269     0.010379
# 97     0.086988     0.000087
# 98     0.374904     0.000375
# 99     0.012928     0.000013
#
# [100 rows x 13 columns]

# %%
# Source - https://stackoverflow.com/questions/17071871/how-do-i-select-rows-from-a-dataframe-based-on-column-values
# Posted by unutbu, modified by community. See post 'Timeline' for change history
# Retrieved 2025-12-03, License - CC BY-SA 4.0

sample_recs_df.loc[~sample_recs_df['filetype'].isin(['.csv','.tsv'])] # .loc is not in-place replacement
# Out:
#     df_index                                fileid  \
# 0       6405  8bce9902-0346-4656-82ec-b6b1d6bef240
# 1       3685  a2436cec-dba4-4440-a919-8b2fdcaee190
# 2      20315  90a13ff8-c322-44bc-8a77-bc1b8c333723
# 4       5420  e1d21bb4-c45f-4d8f-a0b1-95dc4e662951
# 5       4948  48da1e3a-aac9-400e-84f3-846b3a3b90ac
# ..       ...                                   ...
# 83    233432  364818aa-8bfd-445e-bc6b-13931cd76d04
# 84    200900  7b57349d-ac3b-410a-9274-000da07df094
# 94    231961  5593b819-5daf-478a-8339-f4ea8f83a9da
# 97    234789  89141bcd-2ec7-449f-ac40-a477008ca8f7
# 99    235022  4bf5172e-c1aa-4c95-a401-5f76e617bfef
#
#                                               filekey  filesize  \
# 0                           sg512m9d001-178_cmap.xlsx  14555195
# 1              Water Safety Plan Assessment Form.xlsx     18478
# 2              BES LTER Base Cations Data Upload.xlsx     48829
# 4                          COVID-19-data-sharing.xlsx    205131
# 5                     Supplementary_Tables_2_4_5.xlsx     62011
# ..                                                ...       ...
# 83              JPMM_Supp_ResultsTable_30Jun2024.xlsx     96935
# 84  Fatores de Engajamento e Requisitos de Transpa...     13222
# 94                                      Metadata.xlsx     10910
# 97                   VZ4_013_021_VSCHT_S_0347_v1.xlsx     86988
# 99        Bufasi et al. (2024)_ Pre_post_results.xlsx     12928
#
#                             filechecksum  \
# 0   md5:75e68958d0720acde89be59b5c7e11e8
# 1   md5:1dfc6aba3e40f93696e64f113026d35c
# 2   md5:7edfb3ab46d7fdc52bc727e829e8cae6
# 4   md5:562aa3a85cb4d359db88485f39ba8c5c
# 5   md5:8e686b473687e9d5e91cedcf9f4994e7
# ..                                   ...
# 83  md5:7dc7625f8f7cabc5991dfeb54f6b9305
# 84  md5:32d2e480cbb4f63a879023a191ab1c5b
# 94  md5:83a4063583715bb6af927273c56e2879
# 97  md5:191b3d532e484b996b8f9faba6bf13c2
# 99  md5:5c40e27273da10914e93ac6b3ed6c53d
#
#                                        filelinks.self        id  filekey_len  \
# 0   https://zenodo.org/api/records/3700108/files/s...   3700108           25
# 1   https://zenodo.org/api/records/3842933/files/W...   3842933           38
# 2   https://zenodo.org/api/records/3938988/files/B...   3938988           38
# 4   https://zenodo.org/api/records/4246082/files/C...   4246082           26
# 5   https://zenodo.org/api/records/4311139/files/S...   4311139           31
# ..                                                ...       ...          ...
# 83  https://zenodo.org/api/records/12597330/files/...  12597330           37
# 84  https://zenodo.org/api/records/12738460/files/...  12738460           78
# 94  https://zenodo.org/api/records/14182446/files/...  14182446           13
# 97  https://zenodo.org/api/records/14267476/files/...  14267476           32
# 99  https://zenodo.org/api/records/14522238/files/...  14522238           43
#
#    filetype                                     filename_noext  \
# 0     .xlsx                               sg512m9d001-178_cmap
# 1     .xlsx                  Water Safety Plan Assessment Form
# 2     .xlsx                  BES LTER Base Cations Data Upload
# 4     .xlsx                              COVID-19-data-sharing
# 5     .xlsx                         Supplementary_Tables_2_4_5
# ..      ...                                                ...
# 83    .xlsx                   JPMM_Supp_ResultsTable_30Jun2024
# 84    .xlsx  Fatores de Engajamento e Requisitos de Transpa...
# 94    .xlsx                                           Metadata
# 97    .xlsx                        VZ4_013_021_VSCHT_S_0347_v1
# 99    .xlsx             Bufasi et al. (2024)_ Pre_post_results
#
#     filename_noext_len  filesize_mb  filesize_gb
# 0                   20    14.555195     0.014555
# 1                   33     0.018478     0.000018
# 2                   33     0.048829     0.000049
# 4                   21     0.205131     0.000205
# 5                   26     0.062011     0.000062
# ..                 ...          ...          ...
# 83                  32     0.096935     0.000097
# 84                  73     0.013222     0.000013
# 94                   8     0.010910     0.000011
# 97                  27     0.086988     0.000087
# 99                  38     0.012928     0.000013
#
# [61 rows x 13 columns]

# %%
#https://stackoverflow.com/questions/13331698/how-to-apply-a-function-to-two-columns-of-pandas-dataframe
# Source - https://stackoverflow.com/a
# Posted by ajrwhite, modified by community. See post 'Timeline' for change history
# Retrieved 2025-12-03, License - CC BY-SA 4.0

sample_recs_df['sheets'] = sample_recs_df.loc[~sample_recs_df['filetype'].isin(['.csv','.tsv'])].apply(lambda x: sheet_names(x.id, x.filekey), axis=1)

# %%
sample_recs_df
# Out:
#     df_index                                fileid  \
# 0       6405  8bce9902-0346-4656-82ec-b6b1d6bef240
# 1       3685  a2436cec-dba4-4440-a919-8b2fdcaee190
# 2      20315  90a13ff8-c322-44bc-8a77-bc1b8c333723
# 3      11417  a9de2fe1-0292-4744-8479-ebf337336b58
# 4       5420  e1d21bb4-c45f-4d8f-a0b1-95dc4e662951
# ..       ...                                   ...
# 95    252646  5d586cfd-4206-4c42-bce1-54c13401d0d4
# 96    248860  109b149e-3046-4c43-b7d7-9207ac833883
# 97    234789  89141bcd-2ec7-449f-ac40-a477008ca8f7
# 98    249525  024ef7a0-8c2a-4d3d-8591-e27a23c57b77
# 99    235022  4bf5172e-c1aa-4c95-a401-5f76e617bfef
#
#                                         filekey  filesize  \
# 0                     sg512m9d001-178_cmap.xlsx  14555195
# 1        Water Safety Plan Assessment Form.xlsx     18478
# 2        BES LTER Base Cations Data Upload.xlsx     48829
# 3                   Project-3740971-DwC-occ.csv    897957
# 4                    COVID-19-data-sharing.xlsx    205131
# ..                                          ...       ...
# 95                                   icrmsd.csv   5499659
# 96                       LPL1_November_2024.csv  10379269
# 97             VZ4_013_021_VSCHT_S_0347_v1.xlsx     86988
# 98        Underpasses_Dataset_2024_Complete.csv    374904
# 99  Bufasi et al. (2024)_ Pre_post_results.xlsx     12928
#
#                             filechecksum  \
# 0   md5:75e68958d0720acde89be59b5c7e11e8
# 1   md5:1dfc6aba3e40f93696e64f113026d35c
# 2   md5:7edfb3ab46d7fdc52bc727e829e8cae6
# 3   md5:34e2901094489cc08aea5c9c5a90f2bf
# 4   md5:562aa3a85cb4d359db88485f39ba8c5c
# ..                                   ...
# 95  md5:769e52d8490cf6a64c0fb420546e4bd1
# 96  md5:4f10d54d1dc7119a871d63d66797353d
# 97  md5:191b3d532e484b996b8f9faba6bf13c2
# 98  md5:57618c76b669aad210bbb5560d155a93
# 99  md5:5c40e27273da10914e93ac6b3ed6c53d
#
#                                        filelinks.self        id  filekey_len  \
# 0   https://zenodo.org/api/records/3700108/files/s...   3700108           25
# 1   https://zenodo.org/api/records/3842933/files/W...   3842933           38
# 2   https://zenodo.org/api/records/3938988/files/B...   3938988           38
# 3   https://zenodo.org/api/records/3974090/files/P...   3974090           27
# 4   https://zenodo.org/api/records/4246082/files/C...   4246082           26
# ..                                                ...       ...          ...
# 95  https://zenodo.org/api/records/14200591/files/...  14200591           10
# 96  https://zenodo.org/api/records/14257140/files/...  14257140           22
# 97  https://zenodo.org/api/records/14267476/files/...  14267476           32
# 98  https://zenodo.org/api/records/14330681/files/...  14330681           37
# 99  https://zenodo.org/api/records/14522238/files/...  14522238           43
#
#    filetype                          filename_noext  filename_noext_len  \
# 0     .xlsx                    sg512m9d001-178_cmap                  20
# 1     .xlsx       Water Safety Plan Assessment Form                  33
# 2     .xlsx       BES LTER Base Cations Data Upload                  33
# 3      .csv                 Project-3740971-DwC-occ                  23
# 4     .xlsx                   COVID-19-data-sharing                  21
# ..      ...                                     ...                 ...
# 95     .csv                                  icrmsd                   6
# 96     .csv                      LPL1_November_2024                  18
# 97    .xlsx             VZ4_013_021_VSCHT_S_0347_v1                  27
# 98     .csv       Underpasses_Dataset_2024_Complete                  33
# 99    .xlsx  Bufasi et al. (2024)_ Pre_post_results                  38
#
#     filesize_mb  filesize_gb  \
# 0     14.555195     0.014555
# 1      0.018478     0.000018
# 2      0.048829     0.000049
# 3      0.897957     0.000898
# 4      0.205131     0.000205
# ..          ...          ...
# 95     5.499659     0.005500
# 96    10.379269     0.010379
# 97     0.086988     0.000087
# 98     0.374904     0.000375
# 99     0.012928     0.000013
#
#                                                sheets
# 0           [data, dataset_meta_data, vars_meta_data]
# 1                      [Assessment Form, Risk matrix]
# 2   [METADATA, AVG, BARN, DRKR, GFCP, GFGB, GFGL, ...
# 3                                                 NaN
# 4            [Figure 1, Figure 2, Figure 3, Figure 4]
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97              [sim_I, sim_II, sim_III, sim_IV, exp]
# 98                                                NaN
# 99                                         [Pre-Test]
#
# [100 rows x 14 columns]

# %%
sample_recs_df.loc[sample_recs_df['sheets']=='could not parse']
# Out:
# Empty DataFrame
# Columns: [df_index, fileid, filekey, filesize, filechecksum, filelinks.self, id, filekey_len, filetype, filename_noext, filename_noext_len, filesize_mb, filesize_gb, sheets]
# Index: []

# %%
sample_recs_df_exploded
# Out:
#     df_index                                fileid  \
# 0       6405  8bce9902-0346-4656-82ec-b6b1d6bef240
# 0       6405  8bce9902-0346-4656-82ec-b6b1d6bef240
# 0       6405  8bce9902-0346-4656-82ec-b6b1d6bef240
# 1       3685  a2436cec-dba4-4440-a919-8b2fdcaee190
# 1       3685  a2436cec-dba4-4440-a919-8b2fdcaee190
# ..       ...                                   ...
# 97    234789  89141bcd-2ec7-449f-ac40-a477008ca8f7
# 97    234789  89141bcd-2ec7-449f-ac40-a477008ca8f7
# 97    234789  89141bcd-2ec7-449f-ac40-a477008ca8f7
# 98    249525  024ef7a0-8c2a-4d3d-8591-e27a23c57b77
# 99    235022  4bf5172e-c1aa-4c95-a401-5f76e617bfef
#
#                                         filekey  filesize  \
# 0                     sg512m9d001-178_cmap.xlsx  14555195
# 0                     sg512m9d001-178_cmap.xlsx  14555195
# 0                     sg512m9d001-178_cmap.xlsx  14555195
# 1        Water Safety Plan Assessment Form.xlsx     18478
# 1        Water Safety Plan Assessment Form.xlsx     18478
# ..                                          ...       ...
# 97             VZ4_013_021_VSCHT_S_0347_v1.xlsx     86988
# 97             VZ4_013_021_VSCHT_S_0347_v1.xlsx     86988
# 97             VZ4_013_021_VSCHT_S_0347_v1.xlsx     86988
# 98        Underpasses_Dataset_2024_Complete.csv    374904
# 99  Bufasi et al. (2024)_ Pre_post_results.xlsx     12928
#
#                             filechecksum  \
# 0   md5:75e68958d0720acde89be59b5c7e11e8
# 0   md5:75e68958d0720acde89be59b5c7e11e8
# 0   md5:75e68958d0720acde89be59b5c7e11e8
# 1   md5:1dfc6aba3e40f93696e64f113026d35c
# 1   md5:1dfc6aba3e40f93696e64f113026d35c
# ..                                   ...
# 97  md5:191b3d532e484b996b8f9faba6bf13c2
# 97  md5:191b3d532e484b996b8f9faba6bf13c2
# 97  md5:191b3d532e484b996b8f9faba6bf13c2
# 98  md5:57618c76b669aad210bbb5560d155a93
# 99  md5:5c40e27273da10914e93ac6b3ed6c53d
#
#                                        filelinks.self        id  filekey_len  \
# 0   https://zenodo.org/api/records/3700108/files/s...   3700108           25
# 0   https://zenodo.org/api/records/3700108/files/s...   3700108           25
# 0   https://zenodo.org/api/records/3700108/files/s...   3700108           25
# 1   https://zenodo.org/api/records/3842933/files/W...   3842933           38
# 1   https://zenodo.org/api/records/3842933/files/W...   3842933           38
# ..                                                ...       ...          ...
# 97  https://zenodo.org/api/records/14267476/files/...  14267476           32
# 97  https://zenodo.org/api/records/14267476/files/...  14267476           32
# 97  https://zenodo.org/api/records/14267476/files/...  14267476           32
# 98  https://zenodo.org/api/records/14330681/files/...  14330681           37
# 99  https://zenodo.org/api/records/14522238/files/...  14522238           43
#
#    filetype                          filename_noext  filename_noext_len  \
# 0     .xlsx                    sg512m9d001-178_cmap                  20
# 0     .xlsx                    sg512m9d001-178_cmap                  20
# 0     .xlsx                    sg512m9d001-178_cmap                  20
# 1     .xlsx       Water Safety Plan Assessment Form                  33
# 1     .xlsx       Water Safety Plan Assessment Form                  33
# ..      ...                                     ...                 ...
# 97    .xlsx             VZ4_013_021_VSCHT_S_0347_v1                  27
# 97    .xlsx             VZ4_013_021_VSCHT_S_0347_v1                  27
# 97    .xlsx             VZ4_013_021_VSCHT_S_0347_v1                  27
# 98     .csv       Underpasses_Dataset_2024_Complete                  33
# 99    .xlsx  Bufasi et al. (2024)_ Pre_post_results                  38
#
#     filesize_mb  filesize_gb             sheets
# 0     14.555195     0.014555               data
# 0     14.555195     0.014555  dataset_meta_data
# 0     14.555195     0.014555     vars_meta_data
# 1      0.018478     0.000018    Assessment Form
# 1      0.018478     0.000018        Risk matrix
# ..          ...          ...                ...
# 97     0.086988     0.000087            sim_III
# 97     0.086988     0.000087             sim_IV
# 97     0.086988     0.000087                exp
# 98     0.374904     0.000375                NaN
# 99     0.012928     0.000013           Pre-Test
#
# [302 rows x 14 columns]

# %%
sample_recs_df_exploded=sample_recs_df.explode('sheets')

# %%
#https://www.slingacademy.com/article/pandas-how-to-concatenate-strings-from-multiple-columns-in-a-dataframe/
#https://stackoverflow.com/questions/44920796/concatenating-string-and-integers-in-pandas-dataframebased-on-conditions
sample_recs_df_exploded['sheetid'] = sample_recs_df_exploded['id'].astype(str) + '_' + sample_recs_df_exploded['filename_noext'] + '_' + sample_recs_df_exploded['sheets']

# %%
sample_recs_df_exploded['id'] = sample_recs_df_exploded['id'].astype(str)

# %%
sample_recs_df_exploded['sheetid'] = sample_recs_df_exploded[['id', 'filename_noext', 'sheets']].fillna('').agg('_'.join, axis=1).str.strip()

# %%
sample_recs_df_exploded['sheetid']
# Out:
# 0                     3700108_sg512m9d001-178_cmap_data
# 0        3700108_sg512m9d001-178_cmap_dataset_meta_data
# 0           3700108_sg512m9d001-178_cmap_vars_meta_data
# 1     3842933_Water Safety Plan Assessment Form_Asse...
# 1     3842933_Water Safety Plan Assessment Form_Risk...
#                             ...
# 97         14267476_VZ4_013_021_VSCHT_S_0347_v1_sim_III
# 97          14267476_VZ4_013_021_VSCHT_S_0347_v1_sim_IV
# 97             14267476_VZ4_013_021_VSCHT_S_0347_v1_exp
# 98          14330681_Underpasses_Dataset_2024_Complete_
# 99    14522238_Bufasi et al. (2024)_ Pre_post_result...
# Name: sheetid, Length: 302, dtype: object

# %%
filetime = datetime.now()
filetime = filetime.strftime('%Y-%m-%d_%I-%M_%p')

sample_recs_df_exploded.to_csv(f'sample_recs_df_exploded_{filetime}.csv', index_label='sheet_index')
